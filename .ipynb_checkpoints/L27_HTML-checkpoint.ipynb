# %%
import pandas as pd

# %%
url = 'http://www.fdic.gov/bank/individual/failed/banklist.html'

# %%
dframe_list = pd.io.html.read_html(url)

# %%
dframe_list
# Out:
# [                                           Bank Name        City  ST   CERT  \
#  0                                      Resolute Bank      Maumee  OH  58317
#  1                        Louisa Community Bank, Inc.      Louisa  KY  58112
#  2                               The Enloe State Bank      Cooper  TX  10716
#  3                Washington Federal Bank for Savings     Chicago  IL  30570
#  4    The Farmers and Merchants State Bank of Argonia     Argonia  KS  17719
#  ..                                               ...         ...  ..    ...
#  553                               Superior Bank, FSB    Hinsdale  IL  32646
#  554                              Malta National Bank       Malta  OH   6629
#  555                  First Alliance Bank & Trust Co.  Manchester  NH  34264
#  556                National State Bank of Metropolis  Metropolis  IL   3815
#  557                                 Bank of Honolulu    Honolulu  HI  21029
#
# ...

# %%
dframe_list[0]
# Out:
#                                            Bank Name        City  ST   CERT  \
# 0                                      Resolute Bank      Maumee  OH  58317
# 1                        Louisa Community Bank, Inc.      Louisa  KY  58112
# 2                               The Enloe State Bank      Cooper  TX  10716
# 3                Washington Federal Bank for Savings     Chicago  IL  30570
# 4    The Farmers and Merchants State Bank of Argonia     Argonia  KS  17719
# ..                                               ...         ...  ..    ...
# 553                               Superior Bank, FSB    Hinsdale  IL  32646
# 554                              Malta National Bank       Malta  OH   6629
# 555                  First Alliance Bank & Trust Co.  Manchester  NH  34264
# 556                National State Bank of Metropolis  Metropolis  IL   3815
# 557                                 Bank of Honolulu    Honolulu  HI  21029
#
# ...

# %%
url_spla = 'https://stat.ink/entire/weapons2'

# %%
dframe_list_spla = pd.io.html.read_html(url_spla)

# %%
dframe_list_spla[0]
# Out:
#                      Weapon  Sub Weapon  Special  Players   Win %  Avg Kills  \
# 0           Sploosh-o-matic         NaN      NaN   213288  51.90%       2.73
# 1              Splat Roller         NaN      NaN   168517  46.59%       3.73
# 2                 N-ZAP '89         NaN      NaN   165945  48.43%       2.88
# 3                 N-ZAP '85         NaN      NaN   163901  51.05%       3.27
# 4              Splattershot         NaN      NaN   147358  49.10%       3.73
# ..                      ...         ...      ...      ...     ...        ...
# 134  Rapid Blaster Pro Deco         NaN      NaN     3783  43.85%       2.94
# 135       Tenta Camo Brella         NaN      NaN     3509  49.42%       2.78
# 136      Permanent Inkbrush         NaN      NaN     3072  52.21%       2.51
# 137    Bamboozler 14 Mk III         NaN      NaN     2046  43.06%       2.81
# 138   Cherry H-3 Nozzlenose         NaN      NaN     1898  47.58%       3.00
#
# ...

# %%
dframe_spla = dframe_list_spla[0]

# %%
dframe_spla
# Out:
#                      Weapon  Sub Weapon  Special  Players   Win %  Avg Kills  \
# 0           Sploosh-o-matic         NaN      NaN   213288  51.90%       2.73
# 1              Splat Roller         NaN      NaN   168517  46.59%       3.73
# 2                 N-ZAP '89         NaN      NaN   165945  48.43%       2.88
# 3                 N-ZAP '85         NaN      NaN   163901  51.05%       3.27
# 4              Splattershot         NaN      NaN   147358  49.10%       3.73
# ..                      ...         ...      ...      ...     ...        ...
# 134  Rapid Blaster Pro Deco         NaN      NaN     3783  43.85%       2.94
# 135       Tenta Camo Brella         NaN      NaN     3509  49.42%       2.78
# 136      Permanent Inkbrush         NaN      NaN     3072  52.21%       2.51
# 137    Bamboozler 14 Mk III         NaN      NaN     2046  43.06%       2.81
# 138   Cherry H-3 Nozzlenose         NaN      NaN     1898  47.58%       3.00
#
# ...

# %%
dframe_spla.columns
# Out:
# Index(['Weapon', 'Sub Weapon', 'Special', 'Players', 'Win %', 'Avg Kills',
#        'Avg Deaths', 'Kill Ratio', 'Kills/min', 'Deaths/min', 'Avg Specials',
#        'Specials/min', 'Avg Inked', 'Inked/min', 'Inking Performance'],
#       dtype='object')
