# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
nfl_frame
= pd.read_clipboard()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-984889a2a837> in <module>
# ----> 1 nfl_frame = pd.read_clipboard()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      71         )
#      72
# ---> 73     return read_csv(StringIO(text), sep=sep, **kwargs)
#      74
#      75
#
# ...

# %%
nfl_frame = pd.read_clipboard()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-984889a2a837> in <module>
# ----> 1 nfl_frame = pd.read_clipboard()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      71         )
#      72
# ---> 73     return read_csv(StringIO(text), sep=sep, **kwargs)
#      74
#      75
#
# ...

# %%
pd.read_clipboard()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-8cbad928c47b> in <module>
# ----> 1 pd.read_clipboard()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      71         )
#      72
# ---> 73     return read_csv(StringIO(text), sep=sep, **kwargs)
#      74
#      75
#
# ...

# %%
spla_frame=pd.read_clipboard()

# %%
spla_frame
# Out:
#           ブキ   サブウェポン  スペシャル プレーヤー     勝率  平均Kill  平均Death  キルレシオ   キル/分  \
# 0   ボールドマーカー  213,082    NaN  None    NaN     NaN      NaN    NaN    NaN
# 1     51.90%     None    NaN  None    NaN     NaN      NaN    NaN    NaN
# 2       2.73     3.85  0.710     <  0.901   1.269     2.18  0.717  924.5
# 3    スプラローラー  168,341    NaN  None    NaN     NaN      NaN    NaN    NaN
# 4     46.60%     None    NaN  None    NaN     NaN      NaN    NaN    NaN
# 5       3.73     3.80  0.983     <  1.231   1.251     1.26  0.416  630.9
# 6    N-ZAP89  165,788    NaN  None    NaN     NaN      NaN    NaN    NaN
# 7     48.43%     None    NaN  None    NaN     NaN      NaN    NaN    NaN
# 8       2.88     3.18  0.906     <  0.950   1.048     2.57  0.845  834.5
# 9    N-ZAP85  163,824    NaN  None    NaN     NaN      NaN    NaN    NaN
# 10    51.06%     None    NaN  None    NaN     NaN      NaN    NaN    NaN
# 11      3.27     3.56  0.919     <  1.074   1.169     2.20  0.722  842.9
# ...

# %%
spla_frame
# Out:
#              Weapon      Sub Weapon.1 Special  Players    Win     %    Avg  \
# 0   Sploosh-o-matic  213,082     None    None      NaN    NaN   NaN    NaN
# 1            51.90%     None     None    None      NaN    NaN   NaN    NaN
# 2              2.73     3.85    0.710       <    0.901  1.269  2.18  0.717
# 3             Splat   Roller  168,341    None      NaN    NaN   NaN    NaN
# 4            46.60%     None     None    None      NaN    NaN   NaN    NaN
# 5              3.73     3.80    0.983       <    1.231  1.251  1.26  0.416
# 6             N-ZAP      '89  165,788    None      NaN    NaN   NaN    NaN
# 7            48.43%     None     None    None      NaN    NaN   NaN    NaN
# 8              2.88     3.18    0.906       <    0.950  1.048  2.57  0.845
# 9             N-ZAP      '85  163,824    None      NaN    NaN   NaN    NaN
# 10           51.06%     None     None    None      NaN    NaN   NaN    NaN
# ...

# %%
premier_frame = pd.read_clipboard()

# %%
premier_frame
# Out:
#    No.     Season           Champion
# 0    1    1992–93  Manchester United
# 1    2    1993–94  Manchester United
# 2    3    1994–95   Blackburn Rovers
# 3    4    1995–96  Manchester United
# 4    5    1996–97  Manchester United
# 5    6    1997–98            Arsenal
# 6    7    1998–99  Manchester United
# 7    8  1999–2000  Manchester United
# 8    9    2000–01  Manchester United
# 9   10    2001–02            Arsenal

# %%
premier_frame.columns
# Out:
# Index(['No.', 'Season', 'Champion'], dtype='object')

# %%
premier_frame['Season']
# Out:
# 0      1992–93
# 1      1993–94
# 2      1994–95
# 3      1995–96
# 4      1996–97
# 5      1997–98
# 6      1998–99
# 7    1999–2000
# 8      2000–01
# 9      2001–02
# Name: Season, dtype: object

# %%
premier_frame.Season
# Out:
# 0      1992–93
# 1      1993–94
# 2      1994–95
# 3      1995–96
# 4      1996–97
# 5      1997–98
# 6      1998–99
# 7    1999–2000
# 8      2000–01
# 9      2001–02
# Name: Season, dtype: object

# %%
premier_frame[['Season','Champion']]
# Out:
#       Season           Champion
# 0    1992–93  Manchester United
# 1    1993–94  Manchester United
# 2    1994–95   Blackburn Rovers
# 3    1995–96  Manchester United
# 4    1996–97  Manchester United
# 5    1997–98            Arsenal
# 6    1998–99  Manchester United
# 7  1999–2000  Manchester United
# 8    2000–01  Manchester United
# 9    2001–02            Arsenal

# %%
DataFrame(premier_frame, columns=['Season','Champion','City'])
# Out:
#       Season           Champion  City
# 0    1992–93  Manchester United   NaN
# 1    1993–94  Manchester United   NaN
# 2    1994–95   Blackburn Rovers   NaN
# 3    1995–96  Manchester United   NaN
# 4    1996–97  Manchester United   NaN
# 5    1997–98            Arsenal   NaN
# 6    1998–99  Manchester United   NaN
# 7  1999–2000  Manchester United   NaN
# 8    2000–01  Manchester United   NaN
# 9    2001–02            Arsenal   NaN

# %%
premier_frame.head(3)
# Out:
#    No.   Season           Champion
# 0    1  1992–93  Manchester United
# 1    2  1993–94  Manchester United
# 2    3  1994–95   Blackburn Rovers

# %%
premier_frame.tail(3)
# Out:
#    No.     Season           Champion
# 7    8  1999–2000  Manchester United
# 8    9    2000–01  Manchester United
# 9   10    2001–02            Arsenal

# %%
premier_frame.loc()

# %%
premier_frame.iloc[5]
# Out:
# No.               6
# Season      1997–98
# Champion    Arsenal
# Name: 5, dtype: object

# %%
premier_frame.city = 'London'

# %%
premier_frame
# Out:
#    No.     Season           Champion
# 0    1    1992–93  Manchester United
# 1    2    1993–94  Manchester United
# 2    3    1994–95   Blackburn Rovers
# 3    4    1995–96  Manchester United
# 4    5    1996–97  Manchester United
# 5    6    1997–98            Arsenal
# 6    7    1998–99  Manchester United
# 7    8  1999–2000  Manchester United
# 8    9    2000–01  Manchester United
# 9   10    2001–02            Arsenal

# %%
premier_frame = DataFrame(premier_frame, columns=['Season','Champion','City'])

# %%
premier_frame
# Out:
#       Season           Champion  City
# 0    1992–93  Manchester United   NaN
# 1    1993–94  Manchester United   NaN
# 2    1994–95   Blackburn Rovers   NaN
# 3    1995–96  Manchester United   NaN
# 4    1996–97  Manchester United   NaN
# 5    1997–98            Arsenal   NaN
# 6    1998–99  Manchester United   NaN
# 7  1999–2000  Manchester United   NaN
# 8    2000–01  Manchester United   NaN
# 9    2001–02            Arsenal   NaN

# %%
premier_frame.City = 'London'

# %%
premier_frame
# Out:
#       Season           Champion    City
# 0    1992–93  Manchester United  London
# 1    1993–94  Manchester United  London
# 2    1994–95   Blackburn Rovers  London
# 3    1995–96  Manchester United  London
# 4    1996–97  Manchester United  London
# 5    1997–98            Arsenal  London
# 6    1998–99  Manchester United  London
# 7  1999–2000  Manchester United  London
# 8    2000–01  Manchester United  London
# 9    2001–02            Arsenal  London

# %%
premier_frame.City = np.arange(10)

# %%
premier_frame
# Out:
#       Season           Champion  City
# 0    1992–93  Manchester United     0
# 1    1993–94  Manchester United     1
# 2    1994–95   Blackburn Rovers     2
# 3    1995–96  Manchester United     3
# 4    1996–97  Manchester United     4
# 5    1997–98            Arsenal     5
# 6    1998–99  Manchester United     6
# 7  1999–2000  Manchester United     7
# 8    2000–01  Manchester United     8
# 9    2001–02            Arsenal     9

# %%
weapons = Series(["Splatshooter","Wakabashooter"],index=[5,0])

# %%
weapons
# Out:
# 0     Splat shooter
# 1    Wakaba shooter
# 2          N-ZAP 85
# dtype: object

# %%
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])

# %%
weapons = Series(["Splatshooter","Wakabashooter"],index=[5,0])

# %%
weapons
# Out:
# 5     Splatshooter
# 0    Wakabashooter
# dtype: object

# %%
del premier_frame['City']

# %%
premier_frame
# Out:
#       Season           Champion
# 0    1992–93  Manchester United
# 1    1993–94  Manchester United
# 2    1994–95   Blackburn Rovers
# 3    1995–96  Manchester United
# 4    1996–97  Manchester United
# 5    1997–98            Arsenal
# 6    1998–99  Manchester United
# 7  1999–2000  Manchester United
# 8    2000–01  Manchester United
# 9    2001–02            Arsenal

# %%
data = {'City':['SF','LA','NYC'],'Population' :[8370000,3880000,84000000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [8370000, 3880000, 84000000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF     8370000
# 1   LA     3880000
# 2  NYC    84000000
