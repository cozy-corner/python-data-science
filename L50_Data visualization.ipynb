# %%
from numpy.random import randn
import seaborn as sns

# Webブラウザに画像を埋め込むため
# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset)

# %%
sns.distplot(dataset,rug=True, hist=False)

# %%
sns.distplot(dataset, bins=25,
            kde_kws={'color':'indianred','label':'KDE PROT'},
            hist_kws={'color':'blue', 'label':'Histgram'})

# %%
from pandas import Series

# %%
ser1 = Series(dataset, name='My Data')

# %%
ser1
# Out:
# 0    -0.205252
# 1    -0.636604
# 2     0.522874
# 3     1.437760
# 4     0.750280
#         ...
# 95    0.132851
# 96    0.322327
# 97   -0.881869
# 98   -0.105738
# 99    0.915234
# Name: My Data, Length: 100, dtype: float64

# %%
sns.distplot(ser1)
